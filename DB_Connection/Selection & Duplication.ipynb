# %%
import pandas as pd
Filename= 'C:\\Users\\Admin\\Documents\\Code.xlsx'

# %%
df = pd.read_excel(Filename)
df.head()
# Out:
#             name          Company    Designation   Location Region  \
# 0     Amit Singh           Shuttl      Cofounder        NCR  North
# 1   Kamesh Goyal  Digit Insurance       Chairman  Bengaluru  South
# 2    Rahul Samat           Swiggy  Head Strategy  Bengaluru  South
# 3    Shivi Singh       Cleardekho            CEO        NCR  North
# 4  Saurabh Dayal       Cleardekho      Cofounder        NCR  North
#
#                       Email        DB       Person Status Week  \
# 0     amit.singh@shuttl.com  BL Dream  Linkedin Responded  w38
# 1  kamesh.goyal@godigit.com  BL Dream           Connected  w38
# 2     rahul.samat@swiggy.in  BL Dream           Connected  w38
# 3      shivi@cleardekho.com  BL Dream           Connected  w38
# 4    saurabh@cleardekho.com  BL Dream           Connected  w38
#
#                                              Segment Size Lead Owner  \
# 0  Mobile, E-Commerce, Education Technology, E Learn  NaN    Shubham
# 1  Mobile, E-Commerce, Education Technology, E Learn  NaN      Rozer
# 2       Music, Android, Software, Mobile Application  NaN    Shubham
# 3       Music, Android, Software, Mobile Application  NaN    Shubham
# 4  Web Design, iOS, Android, Web Development, Python  NaN    Shubham
#
#   Unnamed: 12
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
#df.sort_values('Organization', inplace=True)
df.shape
# Out:
# (33774, 13)

# %%
df_data = df.drop_duplicates(subset='Email', keep='first')
df_data.shape
# Out:
# (28825, 13)

# %%
df_data
# Out:
#                        name                        Company  \
# 0                Amit Singh                         Shuttl
# 1              Kamesh Goyal                Digit Insurance
# 2               Rahul Samat                         Swiggy
# 3               Shivi Singh                     Cleardekho
# 4             Saurabh Dayal                     Cleardekho
# ...                     ...                            ...
# 33769           lijesh nair                       Appeonix
# 33770      Rajendra Alapaty             E-centricsolutions
# 33771  Shekhar Khandeparkar                       Androcid
# 33772          Jeegar Desai                    Kansoftware
# 33773           swaraj jena  Neukelp Innovation Technology
#
#                    Designation   Location Region  \
# 0                    Cofounder        NCR  North
# 1                     Chairman  Bengaluru  South
# 2                Head Strategy  Bengaluru  South
# 3                          CEO        NCR  North
# 4                    Cofounder        NCR  North
# ...                        ...        ...    ...
# 33769                      NaN        NaN    NaN
# 33770                      NaN        NaN    NaN
# 33771                      NaN        NaN    NaN
# 33772                      NaN        NaN    NaN
# 33773  Co-founder and Director        NaN    NaN
#
#                                          Email        DB       Person Status  \
# 0                        amit.singh@shuttl.com  BL Dream  Linkedin Responded
# 1                     kamesh.goyal@godigit.com  BL Dream           Connected
# 2                        rahul.samat@swiggy.in  BL Dream           Connected
# 3                         shivi@cleardekho.com  BL Dream           Connected
# 4                       saurabh@cleardekho.com  BL Dream           Connected
# ...                                        ...       ...                 ...
# 33769                 lijesh.nair@appeonix.com       NaN                 NaN
# 33770  rajendra.alapaty@e-centricsolutions.com       NaN                 NaN
# 33771         shekhar.khandeparkar@androcid.co       NaN                 NaN
# 33772             jeegar.desai@kansoftware.com       NaN                 NaN
# 33773                       swaraj@neukelp.com       NaN                 NaN
#
#       Week                                            Segment Size Lead Owner  \
# 0      w38  Mobile, E-Commerce, Education Technology, E Learn  NaN    Shubham
# 1      w38  Mobile, E-Commerce, Education Technology, E Learn  NaN      Rozer
# 2      w38       Music, Android, Software, Mobile Application  NaN    Shubham
# 3      w38       Music, Android, Software, Mobile Application  NaN    Shubham
# 4      w38  Web Design, iOS, Android, Web Development, Python  NaN    Shubham
# ...    ...                                                ...  ...        ...
# 33769  NaN                                                NaN  NaN   ########
# 33770  NaN                                                NaN  NaN   ########
# 33771  NaN                                                NaN  NaN   ########
# 33772  NaN                                                NaN  NaN     51-200
# 33773  NaN                                                NaN  NaN   ########
#
#       Unnamed: 12
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 33769         NaN
# 33770         NaN
# 33771         NaN
# 33772         NaN
# 33773         NaN
#
# [28825 rows x 13 columns]

# %%
#df_1 = pd.concat(df[frame] for frame in df.keys())
df_data = df_data.fillna('X')

# %%
df_2 = pd.DataFrame(df_data)

# %%
#df_data = df_2.drop_duplicates(subset='Email', keep='first')
df_2
# Out:
#                        name                        Company  \
# 0                Amit Singh                         Shuttl
# 1              Kamesh Goyal                Digit Insurance
# 2               Rahul Samat                         Swiggy
# 3               Shivi Singh                     Cleardekho
# 4             Saurabh Dayal                     Cleardekho
# ...                     ...                            ...
# 33769           lijesh nair                       Appeonix
# 33770      Rajendra Alapaty             E-centricsolutions
# 33771  Shekhar Khandeparkar                       Androcid
# 33772          Jeegar Desai                    Kansoftware
# 33773           swaraj jena  Neukelp Innovation Technology
#
#                    Designation   Location Region  \
# 0                    Cofounder        NCR  North
# 1                     Chairman  Bengaluru  South
# 2                Head Strategy  Bengaluru  South
# 3                          CEO        NCR  North
# 4                    Cofounder        NCR  North
# ...                        ...        ...    ...
# 33769                        X          X      X
# 33770                        X          X      X
# 33771                        X          X      X
# 33772                        X          X      X
# 33773  Co-founder and Director          X      X
#
#                                          Email        DB       Person Status  \
# 0                        amit.singh@shuttl.com  BL Dream  Linkedin Responded
# 1                     kamesh.goyal@godigit.com  BL Dream           Connected
# 2                        rahul.samat@swiggy.in  BL Dream           Connected
# 3                         shivi@cleardekho.com  BL Dream           Connected
# 4                       saurabh@cleardekho.com  BL Dream           Connected
# ...                                        ...       ...                 ...
# 33769                 lijesh.nair@appeonix.com         X                   X
# 33770  rajendra.alapaty@e-centricsolutions.com         X                   X
# 33771         shekhar.khandeparkar@androcid.co         X                   X
# 33772             jeegar.desai@kansoftware.com         X                   X
# 33773                       swaraj@neukelp.com         X                   X
#
#       Week                                            Segment Size Lead Owner  \
# 0      w38  Mobile, E-Commerce, Education Technology, E Learn    X    Shubham
# 1      w38  Mobile, E-Commerce, Education Technology, E Learn    X      Rozer
# 2      w38       Music, Android, Software, Mobile Application    X    Shubham
# 3      w38       Music, Android, Software, Mobile Application    X    Shubham
# 4      w38  Web Design, iOS, Android, Web Development, Python    X    Shubham
# ...    ...                                                ...  ...        ...
# 33769    X                                                  X    X   ########
# 33770    X                                                  X    X   ########
# 33771    X                                                  X    X   ########
# 33772    X                                                  X    X     51-200
# 33773    X                                                  X    X   ########
#
#       Unnamed: 12
# 0               X
# 1               X
# 2               X
# 3               X
# 4               X
# ...           ...
# 33769           X
# 33770           X
# 33771           X
# 33772           X
# 33773           X
#
# [28825 rows x 13 columns]

# %%
df_data = df_data.to_csv('Contact.csv')

# %%
import pandas as pd

# %%
filepath= "C:\\Users\\Admin\\Downloads\\Marketing_data.xlsx"

# %%
df = pd.read_excel(filepath, sheet_name='Original')
df
# Out:
#                            Domain                        Company   Location  \
# 0                      shuttl.com                         Shuttl        NCR
# 1                     godigit.com                Digit Insurance  Bengaluru
# 2                       swiggy.in                         Swiggy  Bengaluru
# 3                  cleardekho.com                     Cleardekho        NCR
# 4                        acko.com         Acko General Insurance     Mumbai
# ...                           ...                            ...        ...
# 48614          http://androcid.co                       Androcid        NaN
# 48615  http://www.kansoftware.com                    Kansoftware        NaN
# 48616  http://www.kansoftware.com                    Kansoftware        NaN
# 48617     http://www.neukelp.com/  Neukelp Innovation Technology        NaN
# 48618     http://www.neukelp.com/  Neukelp Innovation Technology        NaN
#
#       Region Week  Lead Owner    VC Segment Unnamed: 8
# ...

# %%
df.drop_duplicates(subset='Domain', keep='first', inplace=True)
df.shape
# Out:
# (11610, 9)

# %%
df.to_csv("Filtered_data.csv")
